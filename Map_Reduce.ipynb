# %% [markdown]
# Download data from http://www.gutenberg.org/

# %%
# !wget https://www.gutenberg.org/files/1661/1661-0.txt -O TheAdventuresofSherlockHolmes.txt
# Out:
# --2023-02-23 16:38:51--  https://www.gutenberg.org/files/1661/1661-0.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 607430 (593K) [text/plain]
# Saving to: ‘TheAdventuresofSherlockHolmes.txt’
#
# TheAdventuresofSher 100%[===================>] 593.19K  3.24MB/s    in 0.2s
#
# 2023-02-23 16:38:58 (3.24 MB/s) - ‘TheAdventuresofSherlockHolmes.txt’ saved [607430/607430]

# %% [markdown]
# Import the required library

# %%
import sys;
from itertools import groupby;

# %% [markdown]
# Create map function

# %%
def mapfunc(w):
    # Let us remove all puncuation and spaces.  
    cleanword = ''.join([i for i in w if i.isalpha()])
    return [cleanword,1];

# %% [markdown]
# Create reduce function

# %%
def reducefunc(key, values):
    counts = [x[1] for x in values];
    return [key,sum(counts)];

# %% [markdown]
# Split the document into single word

# %%
with open("TheAdventuresofSherlockHolmes.txt") as f:
    words=[word for line in f for word in line.split()]

# %%
map_result = map (mapfunc, words)

# %%
map_result_sorted = sorted (map_result, key = lambda x: x[0])

# %%
reduce_result = [];
for k, g in groupby(map_result_sorted, key = lambda x: x[0]):
    reduce_result.append(reducefunc(k, list(g)))

# %%
print(reduce_result)
# Out:
# [['', 168], ['A', 104], ['ACTUAL', 1], ['ADLER', 1], ['ADVENTURE', 6], ['ADVENTURES', 2], ['AGREE', 2], ['AGREEMENT', 1], ['AND', 1], ['ANY', 3], ['ANYTHING', 1], ['ARAT', 1], ['ASCII', 2], ['ASIS', 1], ['Abbots', 1], ['Aberdeen', 2], ['About', 10], ['Above', 2], ['Absolute', 1], ['Absolutely', 3], ['Accustomed', 1], ['Across', 1], ['Additional', 1], ['Adler', 15], ['Adventure', 6], ['Adventures', 3], ['Affairs', 1], ['Afghan', 1], ['Afghanistan', 1], ['After', 5], ['Again', 3], ['Agra', 1], ['Ah', 32], ['Air', 1], ['Alas', 2], ['Albert', 3], ['Aldersgate', 1], ['Aldershot', 1], ['Alexander', 1], ['Alice', 11], ['Alices', 1], ['Alicia', 1], ['All', 22], ['Allegro', 2], ['Aloysius', 5], ['Alpha', 7], ['Already', 1], ['Also', 1], ['Altogether', 1], ['Always', 1], ['Amateur', 1], ['America', 10], ['American', 11], ['Americans', 1], ['Amid', 1], ['Among', 2], ['Amoy', 1], ['Ample', 2], ['An', 9], ['And', 200], ['Anderson', 1], ['Andover', 1], ['Angel', 19], ['Angels', 1], ['Angelwas', 1], ['Another', 1], ['Anstruther', 1], ['Any', 2], ['Anybody', 1], ['Anyhow', 2], ['Anything', 1], ['Apache', 1], ['Apaches', 1], ['Apply', 1], ['April', 2], ['Arabian', 1], ['Archery', 1], ['Archie', 1], ['Architecture', 1], ['Archive', 13], ['Are', 6], ['Arizona', 1], ['Armitage', 1], ['ArmitagePercy', 1], ['Armitagethe', 1], ['Armour', 1], ['Arms', 2], ['Arnsworth', 1], ['Arthur', 20], ['Arthurs', 3], ['Artillery', 1], ['As', 82], ['Assizes', 7], ['Astonishment', 1], ['At', 40], ['Atkinson', 1], ['Atlantic', 2], ['Attica', 1], ['Auckland', 1], ['Augustine', 1], ['Australia', 2], ['Australian', 2], ['Australians', 1], ['Author', 1], ['Avenue', 4], ['Awake', 1], ['Away', 2], ['Ay', 1], ['Azure', 1], ['B', 7], ['BACHELOR', 1], ['BALLARAT', 1], ['BAND', 1], ['BE', 1], ['BEECHES', 1], ['BEFORE', 1], ['BERYL', 1], ['BLUE', 1], ['BOHEMIA', 1], ['BOSCOMBE', 1], ['BREACH', 2], ['BUT', 1], ['Bachelor', 1], ['Backwater', 2], ['Backwaters', 1], ['Baker', 42], ['Bakers', 2], ['Ballarat', 5], ['Balmoral', 4], ['Balzac', 1], ['Band', 1], ['Bank', 4], ['Bankers', 1], ['Bar', 1], ['Barque', 1], ['Barton', 1], ['Baxters', 1], ['Be', 3], ['Because', 7], ['Becher', 2], ['Bechers', 1], ['Beeches', 8], ['Before', 1], ['Behind', 1], ['Bengal', 1], ['Berkshire', 4], ['Bermuda', 1], ['Beryl', 2], ['Beside', 2], ['Besides', 10], ['Better', 2], ['Between', 4], ['Beyond', 4], ['Bible', 1], ['Bill', 1], ['Birchmoor', 1], ['Black', 3], ['Bloomsbury', 1], ['Blue', 1], ['Bohemia', 11], ['Bohemian', 4], ['Boone', 7], ['Boonethe', 1], ['Boots', 4], ['Bordeaux', 1], ['Born', 2], ['Boscombe', 15], ['Boswell', 1], ['Botany', 1], ['Both', 6], ['Bought', 1], ['Bow', 2], ['Bradshaw', 2], ['Bradstreet', 12], ['Breckinridge', 7], ['Bridge', 4], ['Briefly', 1], ['Bring', 2], ['Briony', 11], ['Bristol', 6], ['Britain', 1], ['Britannica', 2], ['British', 4], ['Brixton', 6], ['Bs', 1], ['Burnwell', 7], ['But', 182], ['By', 28], ['C', 4], ['CARBUNCLE', 1], ['CASE', 1], ['CONSEQUENTIAL', 1], ['CONTRACT', 1], ['COPPER', 1], ['CORONET', 1], ['Cal', 1], ['Calcutta', 1], ['Calhoun', 2], ['California', 3], ['Californian', 1], ['Camberwell', 2], ['Can', 4], ['Cannon', 1], ['Capital', 3], ['Captain', 2], ['Carbuncle', 1], ['Carefully', 1], ['Carlo', 1], ['Carlsbad', 1], ['Carolinas', 1], ['Case', 1], ['CasselFelstein', 1], ['Castle', 1], ['Catherine', 2], ['Cedars', 3], ['Certainly', 13], ['Chamber', 1], ['Chance', 1], ['Character', 1], ['Charing', 2], ['Charles', 1], ['Charming', 1], ['Chesterfield', 1], ['China', 5], ['Chinese', 1], ['Christmas', 10], ['Christs', 1], ['Chronicle', 2], ['Chubb', 1], ['Church', 3], ['Circumstantial', 2], ['City', 16], ['Civil', 1], ['Clair', 23], ['Clairs', 4], ['Clara', 1], ['Clark', 1], ['Clay', 6], ['Clays', 1], ['Clearly', 1], ['Close', 1], ['Clotilde', 1], ['Club', 1], ['Co', 1], ['Coarse', 1], ['Cobb', 1], ['Coburg', 3], ['Cocksure', 1], ['College', 1], ['Colonel', 15], ['Colony', 1], ['Come', 15], ['Coming', 1], ['Commons', 1], ['Company', 2], ['Compliance', 1] ...
